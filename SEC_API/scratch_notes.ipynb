# %% [markdown]
# ### Scratch notes playing with aggregated data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#from collections import defaultdict
#from pathlib import Path
import json

import os 
import time 

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
russell_df = pd.read_csv('russell_3000_index.csv')

ticker_list = russell_df['Ticker']

# %%
#seeding the DataFrame
#reading the data from a file
with open('SCT_datasets/A_SCTpay_20220906.txt') as f:
    a_txt = f.read()
    
#converting the text string into a dictionary
a_dict = json.loads(a_txt)

starter_df = pd.DataFrame(a_dict)

# %%
start_time = time.time()

for ticker in ticker_list:
    try:
        with open(f'SCT_datasets/{ticker}_SCTpay_20220906.txt') as f:
            ticker_txt = f.read()
        ticker_dict = json.loads(ticker_txt)    
        #ticker_df = pd.DataFrame(ticker_dict)
        starter_df = pd.concat([starter_df,pd.DataFrame(ticker_dict)])
    except:
        print(f'Ticker {ticker} threw an error')
    
        
        
print(f"This code took {time.time() - start_time} seconds")
# Out:
# Ticker XTSLA threw an error
# Ticker USD threw an error
# Ticker MANH threw an error
# Ticker MPW threw an error
# Ticker AFG threw an error
# Ticker GLOB threw an error
# Ticker RRC threw an error
# Ticker UGI threw an error
# Ticker MSFUT threw an error
# Ticker ESU2 threw an error
# Ticker RTYU2 threw an error
# This code took 55.25074815750122 seconds

# %%
starter_df.reset_index(inplace=True,drop=True)

# %%
starter_df.head()
# Out:
#                                  id      cik ticker                 name  \
# 0  73b3a60ba203743c008330c96b7d8b66  1090872      A             Sam Raha
# 1  97393f60cd9f321650e472673daaa70c  1090872      A  Michael R. McMullen
# 2  83b9cc2bca477fe8ce23e0ab56e70c66  1090872      A        Jacob Thaysen
# 3  7c60bb804071675ae15ec930f6dea190  1090872      A       Robert McMahon
# 4  259b710a8befe67c61a2c3dec14f344a  1090872      A    Padraig McDonnell
#
#                                             position  year   salary  bonus  \
# 0  Senior Vice President, President Diagnostics a...  2021   563500      0
# 1                            Chief Executive Officer  2021  1280000      0
# 2  Senior Vice President, President Life Sciences...  2021   625000      0
# 3     Senior Vice President, Chief Financial Officer  2021   663500      0
# 4   Senior Vice President, President Cross-Lab Group  2021   495000      0
#
#    stockAwards  optionAwards  nonEquityIncentiveCompensation  \
# 0      1541332             0                          738536
# 1      9165390             0                         3149714
# 2      1812285             0                          897589
# 3      2291271             0                         1007000
# 4      1249771             0                          686716
#
#    otherCompensation     total  changeInPensionValueAndDeferredEarnings
# 0              33534   3262887                                      NaN
# 1              77512  15967631                                      NaN
# 2              13684   3802349                                      NaN
# 3             176196   4711733                                      NaN
# 4             499472   3243927                                      NaN

# %%
starter_df[starter_df['ticker']=='PEBO']
# Out:
#                                       id     cik ticker  \
# 149365  91c58dad0ee8c8a0fd163df3ec6d162c  318300   PEBO
# 149366  85e1efbe382ba6565f1e37dac31648c7  318300   PEBO
# 149367  ffac9385dff5e2170ff3145a77bb6c8a  318300   PEBO
# 149368  d7738f5cc8b716c0254b95196a2f16da  318300   PEBO
# 149369  c35e3a8e1e9ae69ca06ccfb9807cd543  318300   PEBO
# ...                                  ...     ...    ...
# 149468  52ac6eb16a4df97107f8047396a3a9e2  318300   PEBO
# 149469  3b6ec7a47edaa8cc46ab3eb404ca48b5  318300   PEBO
# 149470  fec9e7192ea8dc8198ae22a0683367b2  318300   PEBO
# 149471  8b10a4e06d0b048ae36d744b6b2472c8  318300   PEBO
# 149472  ef60e15d06b8e6ec4c632f9dfcf02621  318300   PEBO
#
#                          name  \
# 149365  Charles W. Sulerzyski
# 149366         Jason M. Eakle
# 149367      Kathryn M. Bailey
# 149368       Douglas V. Wyatt
# 149369        Tyler J. Wilcox
# ...                       ...
# 149468  Carol A. Schneeberger
# 149469       Larry E. Holdren
# 149470        Mark F. Bradley
# 149471     Joseph S. Yazombek
# 149472         David T. Wesel
#
#                                                  position  year  salary  \
# 149365              President and Chief Executive Officer  2021  658750
# 149366     Executive Vice President, Chief Credit Officer  2021  222500
# 149367  Executive Vice President, Chief Financial Offi...  2021  262500
# 149368  Executive Vice President, Chief Commercial Ban...  2021  287501
# 149369        Executive Vice President, Community Banking  2021  262500
# ...                                                   ...   ...     ...
# 149468  Chief Financial Officer, Treasurer and Executi...  2006  164800
# 149469  Executive Vice President, Business and Corpora...  2006  162080
# 149470              President and Chief Executive Officer  2006  250000
# 149471    Executive Vice President, Chief Lending Officer  2006  200850
# 149472                           Executive Vice President  2006  150000
#
#         bonus  stockAwards  optionAwards  nonEquityIncentiveCompensation  \
# 149365      0       226971             0                          481000
# 149366  10000        29969             0                          100000
# 149367  10000        29969             0                          120000
# 149368  10000        49990             0                          120000
# 149369  10000        39980             0                          120000
# ...       ...          ...           ...                             ...
# 149468      0            0         13950                           27522
# 149469      0            0         11172                           22367
# 149470      0            0          4426                           56750
# 149471      0        17505         42114                           35330
# 149472      0            0          1764                           38100
#
#         otherCompensation    total  changeInPensionValueAndDeferredEarnings
# 149365              94735  1461456                                      0.0
# 149366              28262   390738                                      7.0
# 149367              31438   453907                                      0.0
# 149368              32012   499503                                      0.0
# 149369              32575   465078                                     23.0
# ...                   ...      ...                                      ...
# 149468              11262   245248                                      NaN
# 149469              13036   263952                                      NaN
# 149470              11793   335691                                      NaN
# 149471                  0   309457                                      NaN
# 149472              13840   207177                                      NaN
#
# [108 rows x 14 columns]

# %%
from sec_api import ExecCompApi
import config

# %%
execCompApi = ExecCompApi(config.sec_api_key)

# %%
result_ticker = execCompApi.get_data('XRX')

# %%
max(pd.DataFrame(result_ticker)['salary'])
# Out:
# 10500001

# %%
pd.DataFrame(result_ticker)['year']
# Out:
# 0      2021
# 1      2021
# 2      2021
# 3      2021
# 4      2021
#        ...
# 128    2006
# 129    2006
# 130    2006
# 131    2006
# 132    2006
# Name: year, Length: 133, dtype: int64

# %% [markdown]
# ### Exploring the mistakes

# %%
mistakes_df = pd.read_csv('mistakes.csv').drop(columns='Unnamed: 0')

# %%
mistakes_df['ticker'].value_counts()
# Out:
# MAA     21
# FBMS    12
# CSR      5
# PEBO     2
# PDFS     2
# JEF      1
# CMPR     1
# Name: ticker, dtype: int64
